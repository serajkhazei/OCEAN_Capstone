# %% [markdown]
# # Creating master dataframe

# %% [markdown]
# # Libaries

# %%
import pandas as pd

# %%
df = pd.read_csv('mypersonality_cleaned.csv')
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df.drop(['#AUTHID','sentiNEG','sentiPOS','sentiNEU','sentiCOMPOUND','DATE',
         'NETWORKSIZE','BETWEENNESS','NBETWEENNESS','DENSITY',
         'BROKERAGE','NBROKERAGE','TRANSITIVITY','cEXT','cNEU','cAGR','cCON','cOPN'],axis=1, inplace=True)

# %%
df
# Out:
#                                                  STATUS  sEXT  sNEU  sAGR  \
# 0                           likes the sound of thunder.  2.65  3.00  3.15
# 1     is so sleepy it's not even funny that's she ca...  2.65  3.00  3.15
# 2     is sore and wants the knot of muscles at the b...  2.65  3.00  3.15
# 3            likes how the day sounds in this new song.  2.65  3.00  3.15
# 4                                           is home. <3  2.65  3.00  3.15
# ...                                                 ...   ...   ...   ...
# 9912                       little things give you away.  2.15  2.15  4.10
# 9913                        is wishing it was Saturday.  4.05  3.35  3.80
# 9914                    is studying hard for the G.R.E.  4.05  3.35  3.80
# 9915                              snipers get more head  1.40  4.05  3.30
# 9916  Last night was amazing! Not only did I see *PR...  4.25  3.00  3.25
#
#       sCON  sOPN
# 0     3.25  4.40
# 1     3.25  4.40
# 2     3.25  4.40
# 3     3.25  4.40
# 4     3.25  4.40
# ...    ...   ...
# 9912  2.90  4.60
# 9913  3.95  4.50
# 9914  3.95  4.50
# 9915  3.40  3.95
# 9916  3.50  4.00
#
# [9917 rows x 6 columns]

# %%
df.rename(columns={'sEXT': "Extraversion", 'sNEU': "Neuroticism", 'sAGR':"Agreeablenes",
                   'sCON':"Consciousness" ,'sOPN':"Openness",'STATUS':"status_update"},inplace=True)

# %%
df = df.reindex(['status_update','Openness','Consciousness','Extraversion','Agreeablenes','Neuroticism'], axis=1)

# %%
df
# Out:
#                                           status_update  Openness  \
# 0                           likes the sound of thunder.      4.40
# 1     is so sleepy it's not even funny that's she ca...      4.40
# 2     is sore and wants the knot of muscles at the b...      4.40
# 3            likes how the day sounds in this new song.      4.40
# 4                                           is home. <3      4.40
# ...                                                 ...       ...
# 9912                       little things give you away.      4.60
# 9913                        is wishing it was Saturday.      4.50
# 9914                    is studying hard for the G.R.E.      4.50
# 9915                              snipers get more head      3.95
# 9916  Last night was amazing! Not only did I see *PR...      4.00
#
#       Consciousness  Extraversion  Agreeablenes  Neuroticism
# 0              3.25          2.65          3.15         3.00
# 1              3.25          2.65          3.15         3.00
# 2              3.25          2.65          3.15         3.00
# 3              3.25          2.65          3.15         3.00
# 4              3.25          2.65          3.15         3.00
# ...             ...           ...           ...          ...
# 9912           2.90          2.15          4.10         2.15
# 9913           3.95          4.05          3.80         3.35
# 9914           3.95          4.05          3.80         3.35
# 9915           3.40          1.40          3.30         4.05
# 9916           3.50          4.25          3.25         3.00
#
# [9917 rows x 6 columns]

# %%
df2 = pd.read_csv('final_df.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-7c0f6d1f871c> in <module>
# ----> 1 df2 = pd.read_csv('final_df.csv')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_df.csv'

# %%
df2.drop('userid',axis=1, inplace=True)

# %%
df2.rename(columns={'sEXT': "Extraversion", 'sNEU': "Neuroticism", 
                   'sAGR':"Agreeablenes",'sCON':"Consciousness" ,'sOPN':"Openness"},inplace=True)

# %%
df2

# %%
master_df = pd.concat([df, df2],ignore_index=True)
master_df

# %%
master_df.to_csv('master_data.csv')
